# %%
lst=[]
print(type(lst))
# Out:
# <class 'list'>

# %%
#accessing list items
no=[1, 2, 4, 6, 8]
print(no[4])
print(no[-1]) #-1 will print the last element in the list
print(no[1:])
print(no[1:3])
# Out:
# 8
# 8
# [2, 4, 6, 8]
# [2, 4]

# %%
no[2]=29
print(no)
# Out:
# [1, 2, 29, 6, 8]

# %%
no.append(67)
print(no)
# Out:
# [1, 2, 29, 6, 8, 67]

# %%
no.remove(29) #removing the first occurance of an item
print(no)
# Out:
# [1, 2, 6, 8, 67]

# %%
print(no.pop())
print(no)
# Out:
# 67
# [1, 2, 6, 8]

# %%
print(no.index(6))
# Out:
# 2

# %%
no.insert(2,8)
print(no.count(8))
# Out:
# 2

# %%
no
# Out:
# [1, 2, 8, 6, 8]

# %%
no.sort()
no
# Out:
# [1, 2, 6, 8, 8]

# %%
no.clear()

# %%
no
# Out:
# []

# %%
num=[2,4,5,6,7,8,9,0]
print(num[2:5])
print(num[:5])
print(num[5:])
print(num[::2])
print(num[::-1])
print(num[::-2])
# Out:
# [5, 6, 7]
# [2, 4, 5, 6, 7]
# [8, 9, 0]
# [2, 5, 7, 9]
# [0, 9, 8, 7, 6, 5, 4, 2]
# [0, 8, 6, 4]
